# %% [markdown]
# # Electricity Demand Forecasting

# %% [markdown]
# ### 1. Import Modules

# %%
import pandas as pd
import numpy as np
import re

import json
import datetime


from statsmodels.graphics.tsaplots import plot_acf,plot_pacf 
from statsmodels.tsa.seasonal import seasonal_decompose

from sklearn.preprocessing import StandardScaler

#from pmdarima import auto_arima

from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse


import warnings

from dateutil import parser

import matplotlib.pyplot as plt

from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA

# %% [markdown]
# ### 2. Read Data File

# %%
data_file = '../data/big_demand_temp.csv'

# %%
full_df = pd.read_csv(data_file)
full_df.head()
# Out:
#    Unnamed: 0                       time  demand  Los Angeles  San Diego  \
# 0           0  2020-03-09 14:00:00+00:00   29084        50.35      52.32
# 1           1  2020-03-09 13:00:00+00:00   26088        49.10      51.98
# 2           2  2020-03-09 12:00:00+00:00   24525        49.21      52.82
# 3           3  2020-03-09 11:00:00+00:00   23785        49.88      52.97
# 4           4  2020-03-09 10:00:00+00:00   23759        49.79      53.72
#
#    San Jose  San Francisco  Sacramento  Fresno
# 0     46.07          50.84       50.37   47.14
# 1     46.51          51.19       50.34   47.62
# 2     46.00          51.63       50.41   48.89
# 3     46.72          51.79       50.88   50.79
# 4     47.47          51.70       51.80   51.45

# %%
# Drop the old index column that pandas adds for us
full_df.drop('Unnamed: 0', axis=1, inplace=True)

# Convert the time string to a datetime object
dt_time = [parser.isoparse(x) for x in full_df.loc[:, 'time']]
full_df.index = pd.DatetimeIndex(dt_time)
full_df.drop('time', axis=1, inplace=True)
full_df.sort_index(inplace=True)
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 41114 entries, 2015-07-01 08:00:00+00:00 to 2020-03-09 14:00:00+00:00
# Data columns (total 7 columns):
# demand           41114 non-null int64
# Los Angeles      41114 non-null float64
# San Diego        41114 non-null float64
# San Jose         41114 non-null float64
# San Francisco    41114 non-null float64
# Sacramento       41114 non-null float64
# Fresno           41114 non-null float64
# dtypes: float64(6), int64(1)
# memory usage: 2.5 MB

# %%
full_df.head()
# Out:
#                            demand  Los Angeles  San Diego  San Jose  \
# 2015-07-01 08:00:00+00:00   38210        71.60      68.76     70.89
# 2015-07-01 09:00:00+00:00   35171        70.93      68.19     69.78
# 2015-07-01 10:00:00+00:00   33243        70.43      68.29     68.07
# 2015-07-01 11:00:00+00:00   31955        70.87      68.32     66.92
# 2015-07-01 12:00:00+00:00   31199        71.58      68.46     66.16
#
#                            San Francisco  Sacramento  Fresno
# 2015-07-01 08:00:00+00:00          59.32       79.80   86.04
# 2015-07-01 09:00:00+00:00          58.96       77.77   86.35
# 2015-07-01 10:00:00+00:00          58.63       76.51   82.74
# 2015-07-01 11:00:00+00:00          58.11       74.94   82.04
# 2015-07-01 12:00:00+00:00          57.90       73.80   80.37

# %%
# Split the data into training and test sections
data_len = full_df.shape[0]

# %%
test_len = int(0.5 * data_len)

# %%
X_train = full_df.iloc[:test_len, :]
X_test = full_df.iloc[test_len:, :]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 20557 entries, 2015-07-01 08:00:00+00:00 to 2017-11-03 20:00:00+00:00
# Data columns (total 7 columns):
# demand           20557 non-null int64
# Los Angeles      20557 non-null float64
# San Diego        20557 non-null float64
# San Jose         20557 non-null float64
# San Francisco    20557 non-null float64
# Sacramento       20557 non-null float64
# Fresno           20557 non-null float64
# dtypes: float64(6), int64(1)
# memory usage: 1.3 MB

# %%
scaler = StandardScaler()
demand_data_norm = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)

# %%
demand_data_norm
# Out:
#          demand  Los Angeles  San Diego  San Jose  San Francisco  Sacramento  \
# 0      0.786307     0.420705   0.368223  0.767522       0.052378    1.075604
# 1      0.330346     0.356582   0.297841  0.669832       0.001957    0.935066
# 2      0.041076     0.308729   0.310189  0.519337      -0.044262    0.847836
# 3     -0.152171     0.350840   0.313893  0.418126      -0.117092    0.739144
# 4     -0.265598     0.418791   0.331180  0.351239      -0.146504    0.660222
# ...         ...          ...        ...       ...            ...         ...
# 20552 -0.280452    -0.538267  -0.638111 -0.439081      -0.097484   -0.505617
# 20553 -0.293505    -0.207125  -0.196065 -0.315869       0.056580   -0.419772
# 20554 -0.307759    -0.069309   0.185478 -0.102007       0.291877   -0.331849
# 20555 -0.299507     0.065637   0.411440  0.090733       0.494961   -0.143543
# 20556 -0.309859     0.107747   0.473178  0.338918       0.608408   -0.065312
#
#          Fresno
# 0      1.151235
# ...

# %%
demand_stationary = demand_data_norm.demand - demand_data_norm.demand.shift(1)

scaler_data = scaler.get_params()
demand_mean = scaler.mean_[0]
demand_var = scaler.var_[0]
demand_scale = scaler.scale_[0]

# %%
scaler.mean_
# Out:
# array([32969.22581116,    67.20418446,    65.77787323,    62.16904899,
#           58.94602423,    64.26340517,    67.39988228])

# %%
def build_demand (residual_data) :
    running_demand = 0
    demand_list = np.zeros(len(residual_data))
    for i, val in enumerate(residual_data) :
        running_demand += val
        demand_list[i] = running_demand
        
    return demand_list

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries, window = 12, cutoff = 0.01):

    #Determing rolling statistics
    rolmean = timeseries.rolling(window).mean()
    rolstd = timeseries.rolling(window).std()

    #Plot rolling statistics:
    fig = plt.figure(figsize=(12, 8))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC', maxlag = 20 )
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    pvalue = dftest[1]
    if pvalue < cutoff:
        print('p-value = %.4f. The series is likely stationary.' % pvalue)
    else:
        print('p-value = %.4f. The series is likely non-stationary.' % pvalue)
    
    print(dfoutput)

# %%
test_stationarity(demand_data_norm.demand, window=8)
# Out:
# Results of Dickey-Fuller Test:
# p-value = 0.0008. The series is likely stationary.
# Test Statistic                    -4.142402
# p-value                            0.000823
# #Lags Used                        20.000000
# Number of Observations Used    20536.000000
# Critical Value (1%)               -3.430668
# Critical Value (5%)               -2.861681
# Critical Value (10%)              -2.566845
# dtype: float64

# %%
decomp_data = seasonal_decompose(demand_data_norm.demand[:20000], period=24*7, model='additive')

# %%
decomp_data

# %%
fig = decomp_data.plot()
fig.set_size_inches(15, 12)

# %%
trend_data = decomp_data.trend[84:-84]

# %%
double_decomp = seasonal_decompose(trend_data, period=24*7, model='addititive')

# %%
fig = double_decomp.plot()
fig.set_size_inches(15, 12)

# %%
triple_decomp = seasonal_decompose(double_decomp.trend[84:-84], period=24*365, model='additive')

# %%
fig = triple_decomp.plot()
fig.set_size_inches(15, 12)

# %%
import statsmodels.api as sm

fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(decomp_data.trend, lags=24*365, ax=ax1) # 
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(decomp_data.trend, lags=24*365, ax=ax2)# , lags=40
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-147-d163e514277d> in <module>
#       5 fig = sm.graphics.tsa.plot_acf(decomp_data.trend, lags=24*365, ax=ax1) #
#       6 ax2 = fig.add_subplot(212)
# ----> 7 fig = sm.graphics.tsa.plot_pacf(decomp_data.trend, lags=24*365, ax=ax2)# , lags=40
#
# ~/opt/anaconda3/lib/python3.7/site-packages/statsmodels/graphics/tsaplots.py in plot_pacf(x, ax, lags, alpha, method, use_vlines, title, zero, vlines_kwargs, **kwargs)
#     256         acf_x = pacf(x, nlags=nlags, alpha=alpha, method=method)
#     257     else:
# --> 258         acf_x, confint = pacf(x, nlags=nlags, alpha=alpha, method=method)
#     259
#     260     _plot_corr(ax, title, acf_x, confint, lags, irregular, use_vlines,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py in pacf(x, nlags, method, alpha)
# ...

# %%
city_temps = X_train.columns[1:]

# %%
len(double_decomp.trend), demand_data_norm.shape
# Out:
# (20389, (20557, 7))

# %%
double_decomp.trend[84:-84]
# Out:
# 2015-07-08 08:00:00+00:00    34336.304129
# 2015-07-08 09:00:00+00:00    34324.475756
# 2015-07-08 10:00:00+00:00    34312.856647
# 2015-07-08 11:00:00+00:00    34301.481833
# 2015-07-08 12:00:00+00:00    34290.390687
#                                  ...
# 2017-10-27 16:00:00+00:00    33175.135231
# 2017-10-27 17:00:00+00:00    33140.366071
# 2017-10-27 18:00:00+00:00    33104.672061
# 2017-10-27 19:00:00+00:00    33067.892733
# 2017-10-27 20:00:00+00:00    33029.946429
# Name: trend, Length: 20221, dtype: float64

# %%
demand_data_norm.loc[85:len(double_decomp.trend)-84, city_temps].shape
# Out:
# (20221, 6)

# %%
#model = SARIMAX(double_decomp, exog=demand_data_norm[city_temps].values, order=(15,1,0), simple_differencing=True, seasonal_order=(5, 1, 0, 24))
#model = SARIMAX(demand_data_norm, order=(10,2,0))
model=ARIMA(double_decomp.trend[84:-84],\
    exog=demand_data_norm.loc[85:len(double_decomp.trend)-84, city_temps].values, order=(2,0,0))
res = model.fit()
print(res.summary())
# Out:
# /Users/maboals/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)
# /Users/maboals/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)
# /Users/maboals/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)
# /Users/maboals/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#                                SARIMAX Results
# ...
# Dep. Variable:                  trend   No. Observations:                20221
# ...

# %%
len(res.resid) - len(double_decomp.seasonal), len(double_decomp.seasonal) - len(decomp_data.seasonal)
# Out:
# (-168, -168)

# %%
#demand_hat = build_demand(res.resid[1:]+double_decomp.seasonal) * demand_scale + demand_mean

demand_hat = res.resid + decomp_data.seasonal[168:-168] + double_decomp.seasonal[84:-84]
demand_hat
# Out:
# 2015-07-08 08:00:00+00:00    2002.758257
# 2015-07-08 09:00:00+00:00     271.531279
# 2015-07-08 10:00:00+00:00    1066.728016
# 2015-07-08 11:00:00+00:00     458.812401
# 2015-07-08 12:00:00+00:00    1004.407152
#                                 ...
# 2017-10-27 16:00:00+00:00     357.571648
# 2017-10-27 17:00:00+00:00     271.202547
# 2017-10-27 18:00:00+00:00     754.498289
# 2017-10-27 19:00:00+00:00     756.511428
# 2017-10-27 20:00:00+00:00     440.829480
# Length: 20221, dtype: float64

# %%
np.min(res.resid)
# Out:
# -1800.5635556077286

# %%
fig = plt.figure(figsize=[12, 8])
plt.plot(demand_hat[5:400])
#actual=X_train['demand'].values
plt.ylim(0, 50000)
plt.plot(actual[5:400])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in _fetch_figure_metadata(fig)
#     179         # the background is transparent
#     180         ticksLight = _is_light([label.get_color()
# --> 181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
#     183                                 for label in axis.get_ticklabels()])
#
# ...

# %% [markdown]
# ## actual

# %%
res.resid
# Out:
# array([ 0.89937194, -2.26815878,  1.77510326, ..., -0.0208139 ,
#        -0.00370273, -0.02598136])

# %%
demand_scale
# Out:
# array([6474.01778079])
